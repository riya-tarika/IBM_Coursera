# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import folium

# %%
df=pd.read_csv('C:\\Users\\91863\\Downloads\\Police_Department_Incidents_-_Previous_Year__2016_.csv')

# %%
df.head(15)
# Out:
#     IncidntNum        Category  \
# 0    120058272     WEAPON LAWS
# 1    120058272     WEAPON LAWS
# 2    141059263        WARRANTS
# 3    160013662    NON-CRIMINAL
# 4    160002740    NON-CRIMINAL
# 5    160002869         ASSAULT
# 6    160003130  OTHER OFFENSES
# 7    160003259    NON-CRIMINAL
# 8    160003970        WARRANTS
# 9    160003641  MISSING PERSON
# 10   160086863   LARCENY/THEFT
# 11   160004053    NON-CRIMINAL
# 12   160073014  OTHER OFFENSES
# 13   140776777         ASSAULT
# 14   160004069        BURGLARY
#
#                                              Descript DayOfWeek  \
# 0                           POSS OF PROHIBITED WEAPON    Friday
# 1      FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE    Friday
# 2                                      WARRANT ARREST    Monday
# 3                                       LOST PROPERTY   Tuesday
# 4                                       LOST PROPERTY    Friday
# 5                                             BATTERY    Friday
# ...

# %%
df.drop(['Category','Descript','DayOfWeek','Date','Time','Resolution','Address','X','Y','Location','PdId'],axis=1,inplace=True)

# %%
df.rename(columns={'PdDistrict':'Neighborhood'},inplace=True)
df['count']=df.sum(axis=1)
df.shape
# Out:
# (150500, 3)

# %%
df.head()
# Out:
#    IncidntNum Neighborhood      count
# 0   120058272     SOUTHERN  360174816
# 1   120058272     SOUTHERN  360174816
# 2   141059263      BAYVIEW  423177789
# 3   160013662   TENDERLOIN  480040986
# 4   160002740      MISSION  480008220
